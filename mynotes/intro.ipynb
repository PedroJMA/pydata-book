# %% [markdown]
# Intro 25-07-04

# %%
x=2
y=5
z=x+y

# %%
print(z)
# Out:
# 7

# %% [markdown]
# ## Import conventions
#
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd
# import seaborn as sns
# import statsmodels as sm
